# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# ## Importing Libary

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, precision_recall_curve, confusion_matrix
from collections import Counter

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv('C:/Users/aksha/Desktop/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
fraud_percentage = (df['Class'].value_counts(normalize=True) * 100)
print(fraud_percentage)
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
df.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
fraud = len(df[df['Class'] == 1]) / len(df) * 100
nofraud = len(df[df['Class'] == 0]) / len(df) * 100
fraud_percentage = [nofraud, fraud]
mylabel = ['No Fraud','Fraud']
myexplode = [0.2,0]

plt.pie(fraud_percentage,labels = mylabel,explode = myexplode,autopct='%1.1f%%',startangle = 90)
plt.show()

# %%
df_corr = df.corr()
sns.heatmap(df_corr,annot = False)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ## Somthing

# %%
from sklearn.feature_selection import mutual_info_classif
X = df.drop(columns=['Class'])  
y = df['Class']                 

mi_scores = mutual_info_classif(X, y)

feature_scores = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})

feature_scores = feature_scores.sort_values(by='MI Score', ascending=False)

print("Mutual Information Scores for each feature:")
print(feature_scores)

plt.figure(figsize=(10, 6))
sns.barplot(x='MI Score', y='Feature', data=feature_scores, hue='Feature', palette='viridis', legend=False)
plt.title('Mutual Information Score for Features')
plt.xlabel('MI Score')
plt.ylabel('Feature')
plt.show()
# Out:
# Mutual Information Scores for each feature:
#    Feature  MI Score
# 17     V17  0.008258
# 14     V14  0.008136
# 12     V12  0.007601
# 10     V10  0.007530
# 11     V11  0.006831
# 16     V16  0.006144
# 4       V4  0.004976
# 3       V3  0.004952
# 18     V18  0.004317
# 9       V9  0.004277
# 7       V7  0.003951
# 2       V2  0.003228
# 21     V21  0.002452
# 27     V27  0.002444
# 5       V5  0.002389
# 6       V6  0.002388
# 1       V1  0.002127
# 0     Time  0.001944
# 8       V8  0.001898
# 28     V28  0.001871
# 29  Amount  0.001644
# 19     V19  0.001472
# 20     V20  0.001207
# 23     V23  0.000762
# 24     V24  0.000644
# 26     V26  0.000500
# 25     V25  0.000498
# 13     V13  0.000408
# 22     V22  0.000353
# 15     V15  0.000315

# %%
df = df.drop(["V15","V22","V13","V25","V26","V24"],axis = 1)

# %%
df.shape
# Out:
# (284807, 25)

# %% [markdown]
# ## Spliting Test and Train Dataset

# %%
X = df.drop("Class", axis= 1)
y = df.Class
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Data Preproccessing

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])
X_test['Amount'] = scaler.transform(X_test[['Amount']])

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)
print(Counter(y_train))
print(Counter(y_train_sm))
# Out:
# Counter({0: 190477, 1: 343})
# Counter({0: 190477, 1: 190477})

# %%
y_train_sm.shape

# %% [markdown]
# ## Model

# %% [markdown]
# ### KNN with out tunning

# %% [markdown]
# #### Model Training

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier()
neigh.fit(X_train_sm, y_train_sm)
# Out:
# KNeighborsClassifier(n_neighbors=2, weights='distance')

# %% [markdown]
# #### Model Predicting

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.986796046261717
# F1-score: 0.15978334461746785
# Recall: 0.7919463087248322
# Precision: 0.08885542168674698

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ### KNN with tunning

# %% [markdown]
# #### Finding Best Parameters

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'n_neighbors': [2, 3, 5, 7, 9, 11], 
    'weights': ['uniform', 'distance'], 
    'metric': ['euclidean', 'manhattan', 'minkowski'], 
    'p': [1, 2]
}

grid_search = RandomizedSearchCV(KNeighborsClassifier(),param_grid,cv=2)
grid_search.fit(X_train_sm, y_train_sm)
print("Best Parameters:", grid_search.best_params_)
neigh = grid_search.best_estimator_
# Out:
# Best Parameters: {'weights': 'uniform', 'p': 2, 'n_neighbors': 2, 'metric': 'manhattan'}

# %% [markdown]
# #### Model Training

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=2,weights='uniform',metric='manhattan',p=2)
neigh.fit(X_train_sm, y_train_sm)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=2)

# %% [markdown]
# #### Model Predicting

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9941055677912903
# F1-score: 0.3022670025188917
# Recall: 0.8053691275167785
# Precision: 0.18604651162790697

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ### Decision Tree with out tunning

# %% [markdown]
# #### Model Training

# %%
from sklearn.tree import DecisionTreeClassifier
neigh = DecisionTreeClassifier()
neigh.fit(X_train_sm, y_train_sm)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Model Predicting

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9974783746688372
# F1-score: 0.5052192066805845
# Recall: 0.8120805369127517
# Precision: 0.36666666666666664

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ### Decision Tree with tunning

# %% [markdown]
# #### Finding Best Parameters

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'criterion': ['gini', 'entropy'],  
    'max_depth': [None, 10, 20, 30, 50],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 5, 10],  
    'max_features': ['sqrt', 'log2', None],  
    'class_weight': [None, 'balanced'] 
}

grid_search = RandomizedSearchCV(DecisionTreeClassifier(),param_grid,cv=2,n_jobs=-1)
grid_search.fit(X_train_sm, y_train_sm)
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 30, 'criterion': 'gini', 'class_weight': None}

# %% [markdown]
# #### Model Training

# %%
from sklearn.tree import DecisionTreeClassifier
neigh = DecisionTreeClassifier(class_weight='balanced',criterion='gini',max_depth=30,max_features='log2',min_samples_split=2,min_samples_leaf=1)
neigh.fit(X_train_sm, y_train_sm)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=30,
#                        max_features='log2')

# %%
#### Model Predicting

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9977656484407418
# F1-score: 0.5531914893617021
# Recall: 0.87248322147651
# Precision: 0.40498442367601245

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ### Random Forest with out tunning

# %% [markdown]
# #### Model Training

# %%
from sklearn.ensemble import RandomForestClassifier
neigh = RandomForestClassifier(class_weight='balanced')
neigh.fit(X_train_sm, y_train_sm)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
#### Model Predicting

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9995424899188186
# F1-score: 0.8571428571428571
# Recall: 0.8657718120805369
# Precision: 0.8486842105263158

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ### Random Forest with tunning

# %% [markdown]
# #### Finding Best Parameters

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'n_estimators': [100, 200, 300], 
    'criterion': ['gini', 'entropy'],  
    'max_depth': [None, 10, 20, 30],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],  
    'max_features': ['sqrt', 'log2', None],  
    'class_weight': [None, 'balanced'],  
    'bootstrap': [True, False]
}

grid_search = GridSearchCV(RandomForestClassifier(),param_grid,cv=2)
grid_search.fit(X_train_sm, y_train_sm)
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'entropy', 'class_weight': 'balanced', 'bootstrap': False}

# %% [markdown]
#  #### Model Training

# %%
from sklearn.ensemble import RandomForestClassifier
neigh = RandomForestClassifier(n_estimators=100,class_weight='balanced',criterion='entropy',max_depth=20,min_samples_split=10,min_samples_leaf=2,max_features='sqrt',bootstrap=False )
neigh.fit(X_train_sm, y_train_sm)
# Out:
# RandomForestClassifier(bootstrap=False, class_weight='balanced',
#                        criterion='entropy', max_depth=20, min_samples_leaf=2,
#                        min_samples_split=10)

# %% [markdown]
# #### Model Predicting

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9995318501494888
# F1-score: 0.8543046357615894
# Recall: 0.8657718120805369
# Precision: 0.8431372549019608

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ### XGBOOST without tunning

# %%
import xgboost as xgb
neigh = xgb.XGBClassifier(tree_method='hist',device='cuda')
neigh.fit(X_train_sm, y_train_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9994148126868609
# F1-score: 0.8253968253968254
# Recall: 0.87248322147651
# Precision: 0.7831325301204819

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'n_estimators': [100, 200, 300], 
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  
    'max_depth': [3, 5, 7, 10], 
    'min_child_weight': [1, 3, 5], 
    'subsample': [0.6, 0.8, 1.0], 
    'colsample_bytree': [0.6, 0.8, 1.0],  
    'gamma': [0, 0.1, 0.3, 0.5],  
    'scale_pos_weight': [1, 25, 50, 100]
}

grid_search = RandomizedSearchCV(xgb.XGBClassifier(tree_method='hist',device='cuda'),param_grid,cv=2)
grid_search.fit(X_train_sm, y_train_sm)
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'subsample': 1.0, 'scale_pos_weight': 50, 'n_estimators': 300, 'min_child_weight': 3, 'max_depth': 10, 'learning_rate': 0.2, 'gamma': 0, 'colsample_bytree': 0.6}

# %%
import xgboost as xgb
neigh = xgb.XGBClassifier(tree_method='hist',device='cuda',subsample=1.0,scale_pos_weight=50,n_estimators=300,min_child_weight=3,max_depth=10,learning_rate=0.2,gamma=0,colsample_bytree=0.6)
neigh.fit(X_train_sm, y_train_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = neigh.predict(X_test)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-score:",f1_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Precision:",precision_score(y_test,y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cnf_matrix, annot=True, cmap="Greens" , fmt="d")
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9993190547628927
# F1-score: 0.8024691358024691
# Recall: 0.87248322147651
# Precision: 0.7428571428571429

# %%
y_pred_prob = neigh.predict_proba(X_test)[:, 1] 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()
