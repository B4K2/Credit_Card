# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/aksha/Desktop/Coding/CreditCard/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
fraud_percentage = (df['Class'].value_counts(normalize=True) * 100)
print(fraud_percentage)
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
not_df = df[df['Class'] == 0]
not_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
f_df = df[df['Class'] == 1]
f_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108 -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329 -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
#
# [5 rows x 31 columns]

# %%
df_corr = df.corr()
sns.heatmap(df_corr,annot = False)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dct = DecisionTreeClassifier(class_weight='balanced')
dct.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced')

# %%
y_pred = dct.predict(X_test)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score,\
                            accuracy_score, balanced_accuracy_score,classification_report,\
                            confusion_matrix,accuracy_score

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.71      0.76      0.74       136
#
#     accuracy                           1.00     85443
#    macro avg       0.86      0.88      0.87     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Accuracy: 0.999133925541004

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from collections import Counter
sm = SMOTE(sampling_strategy=0.4286)
scaler = StandardScaler()
pca = PCA(n_components=0.95)
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values
scaler.fit(x)
pca.fit(x)
temp1,temp2 = sm.fit_resample(x,y)
print(Counter(y))
print(Counter(temp2))
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 284315, 1: 121857})

# %%
columns = df.columns
print(columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df = pd.DataFrame(data=temp1,columns = columns[:-1])
df['Class'] = temp2

# %%
df.shape
# Out:
# (406172, 31)

# %%
fraud_percentage = (df['Class'].value_counts(normalize=True) * 100)
print(fraud_percentage)
# Out:
# Class
# 0    69.998671
# 1    30.001329
# Name: proportion, dtype: float64

# %%
df_corr = df.corr()

sns.heatmap(df_corr,annot = False)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dct = DecisionTreeClassifier(class_weight='balanced')
dct.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced')

# %%
y_pred = dct.predict(X_test)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score,\
                            accuracy_score, balanced_accuracy_score,classification_report,\
                            confusion_matrix,accuracy_score

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85298
#            1       0.99      1.00      1.00     36554
#
#     accuracy                           1.00    121852
#    macro avg       1.00      1.00      1.00    121852
# weighted avg       1.00      1.00      1.00    121852
#
# Accuracy: 0.99750517020648

# %%
df = df.drop(df.iloc[:,19:29],axis = 1)
df.shape
# Out:
# (406172, 21)

# %%
df_corr = df.corr()

sns.heatmap(df_corr,annot = False)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dct = DecisionTreeClassifier(class_weight='balanced')
dct.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced')

# %%
y_pred = dct.predict(X_test)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score,\
                            accuracy_score, balanced_accuracy_score,classification_report,\
                            confusion_matrix,accuracy_score

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85298
#            1       0.99      1.00      1.00     36554
#
#     accuracy                           1.00    121852
#    macro avg       1.00      1.00      1.00    121852
# weighted avg       1.00      1.00      1.00    121852
#
# Accuracy: 0.9974805501756229
